# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/DP_LIVE_18102020154144776.csv')
df
# Out:
#       LOCATION  INDICATOR     SUBJECT  ...  TIME   Value  Flag Codes
# 0          AUS  HEALTHEXP         TOT  ...  1971   4.547         NaN
# 1          AUS  HEALTHEXP         TOT  ...  1972   4.547         NaN
# 2          AUS  HEALTHEXP         TOT  ...  1973   4.511         NaN
# 3          AUS  HEALTHEXP         TOT  ...  1974   5.112         NaN
# 4          AUS  HEALTHEXP         TOT  ...  1975   5.760         NaN
# ...        ...        ...         ...  ...   ...     ...         ...
# 16678      SRB  HEALTHEXP  COMPULSORY  ...  2017   4.792         NaN
# 16679      SRB  HEALTHEXP   VOLUNTARY  ...  2017   3.642         NaN
# 16680      SRB  HEALTHEXP      OOPEXP  ...  2017  41.752         NaN
# 16681      SRB  HEALTHEXP  COMPULSORY  ...  2017  56.815         NaN
# 16682      SRB  HEALTHEXP   VOLUNTARY  ...  2017  43.185         NaN
#
# [16683 rows x 8 columns]

# %%
df['Value'].sort_values()
# Out:
# 12168        0.094
# 12167        0.098
# 12164        0.105
# 2739         0.110
# 8118         0.110
#            ...
# 5903      9498.288
# 5904      9880.156
# 5905     10212.748
# 5906     10637.142
# 5907     11071.715
# Name: Value, Length: 16683, dtype: float64

# %%
df.boxplot(by='LOCATION', column = 'Value', grid = False, figsize=(20,25))
plt.title('Total Health Spending per Country', fontsize=24)
plt.xlabel('Country', fontsize=16)
plt.xticks(rotation=270, fontsize=13)
plt.ylabel('Cost per capita (USD)', fontsize=16)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
